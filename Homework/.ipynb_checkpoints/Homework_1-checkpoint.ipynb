# %% [markdown]
# # Вступ до штучного інтелекту та науки про дані

# %% [markdown]
# ## Завдання 1
# Вам потрібно порахувати ключові показники за даними про температуру. Деталі реалізації:
#
# - Створіть Notebook homework_temperature.ipynb.
# - У кодовій комірці створіть список температур: [2, 5, 4, 6, 7, 3, 1].
# - За допомогою функцій Python обчисліть:
#     - середнє значення;
#     - максимальне і мінімальне значення;
#     - різницю між максимальним і мінімальним значенням.
# - Оформіть результати у вигляді таблиці (Markdown).

# %%
from IPython.display import Markdown as md

# %%
temperatures = [2, 5, 4, 6, 7, 3, 1]
md(f"""|Показник|Значення|
|-|-|
|Середнє|{sum(temperatures)/len(temperatures):.2f}|
|Максимум|{max(temperatures)}|
|Мінімум|{min(temperatures)}|
|Різниця між max і min|{max(temperatures) - min(temperatures)}|""")
# Out:
# |Показник|Значення|
# |-|-|
# |Середнє|4.00|
# |Максимум|7|
# |Мінімум|1|
# |Різниця між max і min|6|

# %% [markdown]
# ## Завдання 2:
# Вам необхідно розрахувати показники за списком щоденних витрат. Деталі реалізації:
#
# - Створіть Notebook homework_expenses.ipynb.
# - У кодовій комірці створіть список: [1200, 1500, 800, 600, 1000, 400, 900].
# - Розрахуйте:
#     - загальну суму витрат;
#     - середнє значення;
#     - максимальна і мінімальна витрата;
#     - кількість днів, коли витрата була вищою за 1000.
# - Відобразіть усі результати в таблиці

# %%
expenses = [1200, 1500, 800, 600, 1000, 400, 900]
md(f"""|Показник|Значення|
|-|-|
|Загальна сума|{sum(expenses)}|
|Середнє|{sum(expenses)/len(expenses):.2f}|
|Максимум|{max(expenses)}|
|Мінімум|{min(expenses)}|
|Kількість днів коли витрата була вищою за 1000|{sum(s > 1000 for s in expenses)}|""")
# Out:
# |Показник|Значення|
# |-|-|
# |Загальна сума|6400|
# |Середнє|914.29|
# |Максимум|1500|
# |Мінімум|400|
# |Kількість днів коли витрата була вищою за 1000|2|

# %% [markdown]
# ## Завдання 3
# Вам потрібно обробити список голосів і автоматично знайти лідера. Деталі реалізації:
#
# - Створіть Notebook homework_votes.ipynb.
# - У кодовій комірці створіть список:
#     - votes = ["apple", "banana", "apple", "orange", "banana", "apple", "apple", "apple", "orange"]
# - Використовуючи вбудовані засоби Python (наприклад, count(), dict, або collections.Counter), порахуйте, скільки разів зустрічається кожен фрукт.
# - Напишіть код для визначення фрукта-лідера (зустрічається найбільшу кількість разів).
# - Оформіть результати в таблиці: фрукт → кількість.
# - Окремо покажіть топ-3.

# %%
from collections import Counter
votes = ["apple", "banana", "apple", "orange", "banana", "apple", "apple", "apple", "orange"]
counts = Counter(votes)
ranking = counts.most_common()
top1 = ranking[0][0]
top2 = ranking[1][0]
top3 = ranking[2][0]
print("Fruits leader: ", top1)
md(f"""|фрукт|кількість|
|-|-|
|apple|{votes.count("apple")}|
|banana|{votes.count("banana")}|
|orange|{votes.count("orange")}|""")
# Out:
# Fruits leader:  apple
# |фрукт|кількість|
# |-|-|
# |apple|5|
# |banana|2|
# |orange|2|

# %%
md(f"""|рейтинг|фрукт|
|-|-|
|top-1|{top1}|
|top-2|{top2}|
|top-3|{top3}|""")
# Out:
# |рейтинг|фрукт|
# |-|-|
# |top-1|apple|
# |top-2|banana|
# |top-3|orange|

# %% [markdown]
# ## Завдання 4
# Порівняйте результати з предметів і обчисліть основні показники. Деталі реалізації:
#
# - Створіть Notebook homework_scores.ipynb.
# - У кодовій комірці створіть списки:
#     - math = [80, 92, 75, 60, 88]
#     - physics = [70, 65, 90, 85, 78]
#     - english = [95, 100, 85, 90, 87
# - Для кожного предмета обчисліть:
#     - середній бал;
#     - мінімальний бал;
#     - максимальний бал.
# - Додатково знайдіть предмет з найвищим середнім результатом (кодом, без тексту).
# - Представте результати в таблиці.

# %%
math = [80, 92, 75, 60, 88]
md(f"""|Математика|бал|
|-|-|
|Середній|{sum(math)/len(math):.2f}|
|Мінімальний|{min(math)}|
|Максимальний|{max(math)}|""")
# Out:
# |Математика|бал|
# |-|-|
# |Середній|79.00|
# |Мінімальний|60|
# |Максимальний|92|

# %%
physics = [70, 65, 90, 85, 78]
md(f"""|Фізика|бал|
|-|-|
|Середній|{sum(physics)/len(physics):.2f}|
|Мінімальний|{min(physics)}|
|Максимальний|{max(physics)}|""")
# Out:
# |Фізика|бал|
# |-|-|
# |Середній|77.60|
# |Мінімальний|65|
# |Максимальний|90|

# %%
english = [95, 100, 85, 90, 87]
md(f"""|Англійська мова|бал|
|-|-|
|Середній|{sum(english)/len(english):.2f}|
|Мінімальний|{min(english)}|
|Максимальний|{max(english)}|""")
# Out:
# |Англійська мова|бал|
# |-|-|
# |Середній|91.40|
# |Мінімальний|85|
# |Максимальний|100|

# %%
# Додатково знайдіть предмет з найвищим середнім результатом (кодом, без тексту).
avgs = {"english" : sum(english)/len(english),"physics" : sum(physics)/len(physics),"math" : sum(math)/len(math)}
highestAvg = max(avgs.values())
highestAvg
# Out:
# 91.4
