# %% [markdown]
# # Визначення пневмонії за рентген-знімками
# ## Бізнес-контекст
# Компанія MediScan AI впроваджує модель, яка за рентген-знімками грудної клітки визначає наявність пневмонії.
# Вам необхідно створити і навчити таку модель, використовуючи transfer learning і методи регуляризації.

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

data_dir = './Pract/data/chest_xray'
subdirs = ['test', 'train', 'val']
mean = [0.485, 0.485, 0.485]
std = [0.229, 0.229, 0.229]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize( mean, std )
])

img_datasets = {
    s: datasets.ImageFolder(root=f"{data_dir}/{s}", transform=transform)
    for s in subdirs
}

dataloaders = {
    s: DataLoader(img_datasets[s], batch_size=32, shuffle=(s=='train'), num_workers=4)
    for s in subdirs 
}

class_names = img_datasets[subdirs[0]].classes
print(class_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 16
#      12     transforms.ToTensor(),
#      13     transforms.Normalize( mean, std )
#      14 ])
#      15
# ---> 16 img_datasets = {
#      17     s: datasets.ImageFolder(root=f"{data_dir}/{s}", transform=transform)
#      18     for s in subdirs
#      19 }
#
# File d:\PythonAi\.venv\Lib\site-packages\torchvision\datasets\folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
# ...
